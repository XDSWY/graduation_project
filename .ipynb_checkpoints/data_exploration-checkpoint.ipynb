# %% [markdown]
# # 数据集基本情况
#
# 作者：王越
# 日期：2026年1月23日

# %%
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
print("当前工作目录:", os.getcwd())  # 返回当前工作目录的绝对路径
print("\n目录内容:",os.listdir())   # 返回目录内容
# Out:
# 当前工作目录: C:\Users\lenovo\Desktop\毕设
#
# 目录内容: ['.gitignore', '.idea', '.ipynb_checkpoints', 'config', 'data', 'experiments', 'processed', 'README.md', 'requirements.txt', 'src', 'test', 'thesis', 'Untitled.ipynb', '~$王越-任务书.doc', '王越-任务书.doc']

# %%
df = pd.read_excel('data/raw/ODIR-5K/data.xlsx')
print("\n前5行数据:")
print(df.head())
# Out:
# 前5行数据:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                 Right-Diagnostic Keywords  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# ...

# %%
img_path = "data/raw/ODIR-5K/Training Images/0_left.jpg"
img = Image.open(img_path)
    
display(img) # jupyter专用函数
print(f"图片尺寸: {img.size}")
print(f"图片模式: {img.mode}")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2304x1728>
# 图片尺寸: (2304, 1728)
# 图片模式: RGB
